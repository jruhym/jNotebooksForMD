# %%
cd /home/drew/NBOH/branchOffMd
# Out:
# /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd

# %%
from glob import glob
import asyncio, nest_asyncio
import bioinf as bi

ligand_nickname = 'NBOH'

nest_asyncio.apply() #https://github.com/jupyter/notebook/issues/3397#issuecomment-419386811

directories = glob("run??")

cmds = [
    bi.run_async_shell_cmd(
        f'cd {directory}; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod', 
        [], do_stdout=False, do_stderr=True, requires_kill=False
    ) for directory in directories
]

async def main():
    await asyncio.gather(*cmds)
    
asyncio.run(main())
# Out:
# ['cd run03; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 1]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run03/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# -------------------------------------------------------
# Program:     gmx chi, version 2022.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -f
#     File '../md_0_2.xtc' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#
# ['cd run09; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 1]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run09/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# -------------------------------------------------------
# Program:     gmx chi, version 2022.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -f
#     File '../md_0_2.xtc' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#
# ['cd run12; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 1]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run12/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# -------------------------------------------------------
# Program:     gmx chi, version 2022.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -f
#     File '../md_0_2.xtc' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#
# ['cd run08; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run08/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     418978
# Time between transitions:       752.456 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)
#
#
# ['cd run11; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run11/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     444387
# Time between transitions:       709.433 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)
#
#
# ['cd run05; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run05/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     446074
# Time between transitions:       706.750 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)
#
#
# ['cd run07; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run07/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     451127
# Time between transitions:       698.833 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)
#
#
# ['cd run02; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run02/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     434216
# Time between transitions:       726.050 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)
#
#
# ['cd run10; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run10/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     423002
# Time between transitions:       745.298 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)
#
#
# ['cd run06; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run06/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     447311
# Time between transitions:       704.795 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)
#
#
# ['cd run04; mkdir chi; cd chi; gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod' exited with 0]
# [stderr]
# mkdir: cannot create directory ‘chi’: File exists
#                        :-) GROMACS - gmx chi, 2022.3 (-:
#
# Executable:   /usr/local/gromacs-2022.3/bin/gmx
# Data prefix:  /usr/local/gromacs-2022.3
# Working dir:  /scr/drew/Serotonin/6WHA/equilibration/tryIonicCapsInSolvent/di-S-bond_ECL3/6WGTTmplt4EXL3/Desmond/Hirshfeld/retry/blockMembraneBackdoor/retry/branchOffMd/run04/chi
# Command line:
#   gmx chi -s ../md_0_1.pdb -f ../md_0_2.xtc -all -maxchi 2 -o -p -ot -rt -jc -cp -chi_prod
#
#
# 278 residues with dihedrals found
# 1331 dihedrals found
# Last frame      25000 time 250000.000
# j after resetting (nr. active dihedrals) = 1261
# Printing chi2LYS278.xvg
# WARNING: not all dihedrals found in topology (only 1261 out of 1331)!
# Now calculating transitions...
# Total number of transitions:     433664
# Time between transitions:       726.974 ps
# Now printing out transitions and OPs...
# Now printing out rotamer occupancies...
# Now calculating Chi product trajectories...
# Printing chiproductLYS278.xvg    and histo-chiprodLYS278.xvg
#
# gmx chi is deprecated.
# See https://gitlab.com/gromacs/gromacs/-/issues/4108 if
# you are interested in preserving it!
#
# GROMACS reminds you: "Thou shalt not kill -9" (Anonymous)

# %%
inputs
# Out:
# ['CMYH', 'DPPC', '\x03']
